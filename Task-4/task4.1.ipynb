# %% [markdown]
# Summer - Task 04 👨🏻‍💻
#
# ⚜️ Team Task
#
# Task Description 📄
#
# 🔅 Task 4.1
# 📌 Create image by yourself Using Python Code
#
# 🔅 Task 4.2
# 📌 Take 2 image crop some part of both image and swap it.
#
# 🔅 Task 4.3
# 📌 Take 2 image and combine it to form single image. For example collage
#
# ▪️ Do this Team Task.
#
# ⚠️ Deadline: 9th June, 2021 | 11:59 P.M.
#
# 📍Below are the hashtags you have to use while posting your task
# #vimaldaga #righteducation #educationredefine #rightmentor #worldrecordholder #linuxworld #makingindiafutureready #righeducation #summertraining
#
# 📥 Submission form : http://bit.ly/summer-task-4
#
# Thanks and Regards
# Team LW ✨

# %%
import cv2 
import numpy as np

frame = np.ones((400,500))

def  picshow(photo):
        cv2.imshow("my photo", photo)
        cv2.waitKey()
        cv2.destroyAllWindows()

frame_test = frame.copy()

head = cv2.circle(frame_test,center=(130,156),radius=50,thickness= -1,color=(0.4,1))

eye = cv2.circle(frame_test,center=(100,156),radius=5,thickness=-1,color=(0,0,255))

#eyeline = cv2.line(frame_test,(90,90),(100,100),thickness= 3,color=(0,0,255))


image = cv2.ellipse(frame_test, center = (300, 180),axes = (120, 75),
          angle = 0, startAngle = 0,endAngle = 360,color = (0, 0, 255), thickness = 5)

image1 = cv2.ellipse(frame_test, center = (310, 180),axes = (60, 40),
          angle = 0, startAngle = 0,endAngle = 360,color = (0, 255,0), thickness = -1)


pts = np.array([[85, 180], [80, 160], 
                [30, 180+30]],np.int32)
  
pts = pts.reshape((-1, 1, 2))
  
isClosed = True

color = (0, 0, 0)

thickness = 2
  

image = cv2.polylines(frame_test, [pts], 
                      isClosed, color, thickness)

pts = np.array([[250+20, 250], [180+40, 290], 
                [230+20, 310]],np.int32)
  
pts = pts.reshape((-1, 1, 2))
  
isClosed = True
  

color = (0, 0, 0)
  

thickness = 2
  

image = cv2.polylines(frame_test, [pts], 
                      isClosed, color, thickness)

X = 70
pts1 = np.array([[250+X, 250], [300+X, 290], 
                [270+X, 310]],np.int32)

  
pts1 = pts1.reshape((-1, 1, 2))
  
isClosed = True
  

color = (0, 0, 0)
  

thickness = 2
  

image = cv2.polylines(frame_test, [pts1], 
                      isClosed, color, thickness)

pts2 = np.array([[420, 180], [420+50, 200], 
                [420+50, 160]],np.int32)
  
pts2 = pts2.reshape((-1, 1, 2))
  
isClosed = True
  

color = (0, 0, 0)
  

thickness = 2
  

image = cv2.polylines(frame_test, [pts2], 
                      isClosed, color, thickness)

picshow(frame_test)
